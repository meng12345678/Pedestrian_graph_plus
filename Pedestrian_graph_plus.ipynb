# %% [markdown]
# <a href="https://colab.research.google.com/github/meng12345678/Pedestrian_graph_plus/blob/main/Pedestrian_graph_plus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Install
# !git clone https://github.com/meng12345678/Pedestrian_graph_plus
# !pip install --upgrade --no-cache-dir gdown
# !pip3 install pytorch-lightning
# Out:
# Cloning into 'Pedestrian_graph_plus'...
# remote: Enumerating objects: 196, done.
# remote: Counting objects: 100% (196/196), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 196 (delta 62), reused 112 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (196/196), 26.87 MiB | 12.19 MiB/s, done.
# Resolving deltas: 100% (62/62), done.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.1/823.1 kB 44.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 63.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...

# %%
#@title Install

# !gdown 1xuJz0pWAevZ-3YKbUttyOp01X_mry-6r -O /content/Pedestrian_graph_plus/data.zip  # data
# !gdown 1s6-xV4j_rzrqIPDtRvY_xFB1lp46drS7 -O /content/Pedestrian_graph_plus/pie.zip  # pie
# !gdown 17RKd3AxQIFJEdw7CfHrvG1Fg2ZWOcoB3 -O /content/Pedestrian_graph_plus/jaad.zip  # jaad

# !unzip /content/Pedestrian_graph_plus/data.zip -d /content/Pedestrian_graph_plus
# !unzip /content/Pedestrian_graph_plus/pie.zip -d /content/Pedestrian_graph_plus
# !unzip /content/Pedestrian_graph_plus/jaad.zip -d /content/Pedestrian_graph_plus
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set02_video_0002_pid_2_2_166_fr_12813.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set04_video_0002_pid_4_2_1050_fr_01473.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set04_video_0003_pid_4_3_1142_fr_05866.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set04_video_0005_pid_4_5_1221_fr_13477.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set04_video_0010_pid_4_10_1493_fr_05446.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set04_video_0016_pid_4_16_1725_fr_11962.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set03_video_0008_pid_3_8_532_fr_05825.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set03_video_0009_pid_3_9_589_fr_03301.pkl
#   inflating: /content/Pedestrian_graph_plus/data/PIE/data/set03_video_0009_pid_3_9_626_fr_15827.pkl
# ...

# %%
import os
os.chdir('/content/Pedestrian_graph_plus')
# !python3 pl_jaad_muster23_forecast_111.py --logdir ./weigths/jaad-23-IVSFT-h2d/
# Out:
# loading train data in memory: 100% 23385/23385 [00:42<00:00, 547.22it/s]
# loading test data in memory: 100% 18112/18112 [00:28<00:00, 624.62it/s]
# loading val data in memory: 100% 3402/3402 [00:02<00:00, 1192.11it/s]
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# 2025-06-13 16:28:34.086885: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749832114.351440    9176 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python3 pl_pie_muster23_forecast_111.py --logdir ./weigths/jaad-23-IVSFT/
# Out:
# loading train data in memory: 100% 1000/1000 [00:04<00:00, 216.68it/s]
# loading test data in memory: 100% 1000/1000 [00:04<00:00, 221.79it/s]
# loading val data in memory: 100% 1000/1000 [00:04<00:00, 236.08it/s]
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# 2025-04-25 21:46:27.593815: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745617587.614624   23756 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
import os
os.chdir('/content/Pedestrian_graph_plus')
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/best.pth
# Out:
# Loading from .pth format
# loading test data in memory: 100% 5821/5821 [00:01<00:00, 4733.62it/s]
# Testing samples: 100% 5821/5821 [00:38<00:00, 153.07it/s]
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# balance data: False, bh: all, last2: False, Model: jaad-23-IVSFT-h2d
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Models statistics
#            accuracy_score   f1_score  ...  roc_auc_score  average_precision_score
# PCPA            70.932829  51.490826  ...      85.454657                48.247463
# Glob_PCPA       83.490809  63.858593  ...      86.097297                54.896822
# FUSSI           60.951727  40.010557  ...      72.934193                37.856634
# PedGraph+       66.466243  26.561324  ...      54.078114                19.170236
#
# [4 rows x 6 columns]
# No crossing: 89.589
# Crossing: 66.449
# Irrelevant 64.456
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Weather statistics
# ...

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/jaad23-epoch=06-val_acc=85.714.ckpt
# Out:
# Loading from .ckpt format
# loading test data in memory: 100% 5821/5821 [00:01<00:00, 5036.09it/s]
# Testing samples: 100% 5821/5821 [00:37<00:00, 153.53it/s]
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# balance data: False, bh: all, last2: False, Model: jaad-23-IVSFT-h2d
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Models statistics
#            accuracy_score   f1_score  ...  roc_auc_score  average_precision_score
# PCPA            70.932829  51.490826  ...      85.454657                48.247463
# Glob_PCPA       83.490809  63.858593  ...      86.097297                54.896822
# FUSSI           60.951727  40.010557  ...      72.934193                37.856634
# PedGraph+       72.925614   8.690614  ...      45.252904                16.764068
#
# [4 rows x 6 columns]
# No crossing: 84.195
# Crossing: 72.599
# Irrelevant 60.797
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Weather statistics
# ...

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/jaad23-epoch=13-val_acc=85.861.ckpt
# Out:
# Loading from .ckpt format
# loading test data in memory: 100% 5821/5821 [00:01<00:00, 4923.50it/s]
# Testing samples: 100% 5821/5821 [00:37<00:00, 154.91it/s]
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# balance data: False, bh: all, last2: False, Model: jaad-23-IVSFT-h2d
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Models statistics
#            accuracy_score   f1_score  ...  roc_auc_score  average_precision_score
# PCPA            70.932829  51.490826  ...      85.454657                48.247463
# Glob_PCPA       83.490809  63.858593  ...      86.097297                54.896822
# FUSSI           60.951727  40.010557  ...      72.934193                37.856634
# PedGraph+       26.902594  29.681044  ...      50.815944                17.854927
#
# [4 rows x 6 columns]
# No crossing: 89.572
# Crossing: 26.868
# Irrelevant 34.599
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Weather statistics
# ...

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/jaad23-epoch=21-val_acc=85.891.ckpt
# Out:
# Loading from .ckpt format
# loading test data in memory: 100% 5821/5821 [00:01<00:00, 5038.96it/s]
# Testing samples: 100% 5821/5821 [00:37<00:00, 154.47it/s]
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# balance data: False, bh: all, last2: False, Model: jaad-23-IVSFT-h2d
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Models statistics
#            accuracy_score   f1_score  ...  roc_auc_score  average_precision_score
# PCPA            70.932829  51.490826  ...      85.454657                48.247463
# Glob_PCPA       83.490809  63.858593  ...      86.097297                54.896822
# FUSSI           60.951727  40.010557  ...      72.934193                37.856634
# PedGraph+       66.466243  26.561324  ...      54.078114                19.170236
#
# [4 rows x 6 columns]
# No crossing: 89.589
# Crossing: 66.449
# Irrelevant 64.456
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Weather statistics
# ...

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/jaad23-epoch=05-val_acc=85.685.ckpt
# Out:
# Loading from .ckpt format
# loading test data in memory: 100% 5821/5821 [00:01<00:00, 4948.79it/s]
# Testing samples: 100% 5821/5821 [00:37<00:00, 153.88it/s]
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# balance data: False, bh: all, last2: False, Model: jaad-23-IVSFT-h2d
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Models statistics
#            accuracy_score   f1_score  ...  roc_auc_score  average_precision_score
# PCPA            70.932829  51.490826  ...      85.454657                48.247463
# Glob_PCPA       83.490809  63.858593  ...      86.097297                54.896822
# FUSSI           60.951727  40.010557  ...      72.934193                37.856634
# PedGraph+       80.879574   2.110818  ...      47.656991                17.334890
#
# [4 rows x 6 columns]
# No crossing: 12.369
# Crossing: 80.880
# Irrelevant 28.054
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Weather statistics
# ...

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_07.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_08.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_09.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_10.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_11.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_12.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_13.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_14.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_15.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_16.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_17.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_18.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_19.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_20.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_21.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_22.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_jaad_test.py --ckpt ./weigths/jaad-23-IVSFT-h2d/epoch_models/epoch_23.pth

# %%
# !python3 /content/Pedestrian_graph_plus/final_pie_test.py --ckpt ./weigths/jaad-23-IVSFT/best.pth
# Out:
# /content/Pedestrian_graph_plus/final_pie_test.py:1: DeprecationWarning: numpy.core.fromnumeric is deprecated and has been renamed to numpy._core.fromnumeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.fromnumeric.argmax.
#   from numpy.core.fromnumeric import argmax
# loading test data in memory: 100% 3114/3114 [00:11<00:00, 278.80it/s]
# Testing samples: 100% 3114/3114 [00:19<00:00, 163.43it/s]
# balance data: False, bh: all, last2: False, Model: jaad-23-IVSFT
#            accuracy_score  ...  average_precision_score
# PCPA            86.223507  ...                 0.789816
# ...
